# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates # The date plotting capabilites

# %%
df_tesla = pd.read_csv("TESLA Search Trend vs Price.csv")

# %%
df_tesla.head()
# Out:
#         MONTH  TSLA_WEB_SEARCH  TSLA_USD_CLOSE
# 0  2010-06-01                3           4.766
# 1  2010-07-01                3           3.988
# 2  2010-08-01                2           3.896
# 3  2010-09-01                2           4.082
# 4  2010-10-01                2           4.368

# %%
print("This is a simple df, it consists of 3 columns, depicting a month, num of tesla searches and the closing price. ")
# Out:
# This is a simple df, it consists of 3 columns, depicting a month, num of tesla searches and the closing price.

# %%
print(f"Size of data: {df_tesla.shape}")
# Out:
# Size of data: (124, 3)

# %%
print("we have 124 rows and 3 columns")
# Out:
# we have 124 rows and 3 columns

# %%
print(f"The columns are: {df_tesla.columns}")
# Out:
# The columns are: Index(['MONTH', 'TSLA_WEB_SEARCH', 'TSLA_USD_CLOSE'], dtype='object')

# %%
print("Let us look at some antibiotics")
# Out:
# Let us look at some antibiotics

# %%
df_tesla.describe()
# Out:
#        TSLA_WEB_SEARCH  TSLA_USD_CLOSE
# count       124.000000      124.000000
# mean          8.725806       50.962145
# std           5.870332       65.908389
# min           2.000000        3.896000
# 25%           3.750000        7.352500
# 50%           8.000000       44.653000
# 75%          12.000000       58.991999
# max          31.000000      498.320007

# %%
print("The mean number of searches is a measure for the avg number of searches, can be affected by outliers \n")
print("The mean number for closing price is a measure for the avg closing price, can be affeced by outliers \n")
print("The standard deviation value is a depiction of how varied values are from the mean, the standard deviation for tesla is high\n")
print("This means that most closing prices are further from the mean\n")
print("We also have Q1-Q2-Q3\n")
print("We notice that the highest number of searches for some date is 31\n")
print("The max closing price is $498, this is an absolute ridiculous value as opposed to the mean")
# Out:
# The mean number of searches is a measure for the avg number of searches, can be affected by outliers
#
# The mean number for closing price is a measure for the avg closing price, can be affeced by outliers
#
# The standard deviation value is a depiction of how varied values are from the mean, the standard deviation for tesla is high
#
# This means that most closing prices are further from the mean
#
# We also have Q1-Q2-Q3
#
# We notice that the highest number of searches for some date is 31
#
# The max closing price is $498, this is an absolute ridiculous value as opposed to the mean

# %%
# What is the periodicity of the time series data?

# %%
df_tesla.MONTH
# Out:
# 0      2010-06-01
# 1      2010-07-01
# 2      2010-08-01
# 3      2010-09-01
# 4      2010-10-01
#           ...
# 119    2020-05-01
# 120    2020-06-01
# 121    2020-07-01
# 122    2020-08-01
# 123    2020-09-01
# Name: MONTH, Length: 124, dtype: object

# %%
df_tesla.MONTH = pd.to_datetime(df_tesla.MONTH) # Let us convert the column into a datetime month

# %%
print(f" Let us grab a sample subtraction to see what time frame we are working with {df_tesla.MONTH[1] - df_tesla.MONTH[0]}")
# Out:
#  Let us grab a sample subtraction to see what time frame we are working with 30 days 00:00:00

# %%
print("Let us shift values 1 forward so we can minus all rows from prior row")
df_tesla.MONTH.shift(1) - df_tesla.MONTH
# Out:
# Let us shift values 1 forward so we can minus all rows from prior row
# 0          NaT
# 1     -30 days
# 2     -31 days
# 3     -31 days
# 4     -30 days
#         ...
# 119   -30 days
# 120   -31 days
# 121   -30 days
# 122   -31 days
# 123   -31 days
# Name: MONTH, Length: 124, dtype: timedelta64[ns]

# %%
print("We conclude 1 month as periodicity")
# Out:
# We conclude 1 month as periodicity

# %%
df_unemployed = pd.read_csv("UE Benefits Search vs UE Rate 2004-20.csv")

# %%
df_unemployed.head()
# Out:
#      MONTH  UE_BENEFITS_WEB_SEARCH  UNRATE
# 0  2004-01                       9     5.7
# 1  2004-02                       8     5.6
# 2  2004-03                       7     5.8
# 3  2004-04                       8     5.6
# 4  2004-05                       6     5.6

# %%
print(f"How many rows and columns do we have in the unemployment df: {df_unemployed.shape}")
# Out:
# How many rows and columns do we have in the unemployment df: (200, 3)

# %%
df_unemployed.columns
# Out:
# Index(['MONTH', 'UE_BENEFITS_WEB_SEARCH', 'UNRATE'], dtype='object')

# %%
df_unemployed.describe()
# Out:
#        UE_BENEFITS_WEB_SEARCH      UNRATE
# count              200.000000  200.000000
# mean                10.315000    6.173000
# std                 10.778061    2.128267
# min                  4.000000    3.500000
# 25%                  5.000000    4.600000
# 50%                  7.000000    5.400000
# 75%                 12.000000    7.825000
# max                100.000000   14.700000

# %%
print("The standard deviation of the unrate is lower than the mean, indicating there is little variance in the " 
      "data values \nWe can say that the UE rate has remained stable, excluding the rate at 14%")
# Out:
# The standard deviation of the unrate is lower than the mean, indicating there is little variance in the data values
# We can say that the UE rate has remained stable, excluding the rate at 14%

# %%
df_unemployed.head()
# Out:
#      MONTH  UE_BENEFITS_WEB_SEARCH  UNRATE
# 0  2004-01                       9     5.7
# 1  2004-02                       8     5.6
# 2  2004-03                       7     5.8
# 3  2004-04                       8     5.6
# 4  2004-05                       6     5.6

# %%
df_unemployed.MONTH =  pd.to_datetime(df_unemployed.MONTH)

# %%
# Let us find periodicity
df_unemployed.MONTH.shift(1) - df_unemployed.MONTH
# Out:
# 0          NaT
# 1     -31 days
# 2     -29 days
# 3     -31 days
# 4     -30 days
#         ...
# 195   -31 days
# 196   -30 days
# 197   -31 days
# 198   -30 days
# 199   -31 days
# Name: MONTH, Length: 200, dtype: timedelta64[ns]

# %%
print("Again 1 month")
# Out:
# Again 1 month

# %%
df_bitcoin_search_tread = pd.read_csv("Bitcoin Search Trend.csv")

# %%
df_bitcoin_daily_price = pd.read_csv("Daily Bitcoin Price.csv")

# %%
df_bitcoin_search_tread.head()
# Out:
#      MONTH  BTC_NEWS_SEARCH
# 0  2014-09                5
# 1  2014-10                4
# 2  2014-11                4
# 3  2014-12                4
# 4  2015-01                5

# %%
df_bitcoin_daily_price.head()
# Out:
#          DATE       CLOSE      VOLUME
# 0  2014-09-17  457.334015  21056800.0
# 1  2014-09-18  424.440002  34483200.0
# 2  2014-09-19  394.795990  37919700.0
# 3  2014-09-20  408.903992  36863600.0
# 4  2014-09-21  398.821014  26580100.0

# %%
# Can we combine these? Well we have 2 time columns that are different so no

# %%
df_bitcoin_search_tread.shape
# Out:
# (73, 2)

# %%
df_bitcoin_daily_price.shape # 2204 days of data
# Out:
# (2204, 3)

# %%
df_bitcoin_daily_price.describe()
# Out:
#               CLOSE        VOLUME
# count   2203.000000  2.203000e+03
# mean    4429.421245  8.043622e+09
# std     4148.150071  1.176529e+10
# min      178.102997  5.914570e+06
# 25%      433.629502  6.029915e+07
# 50%     3637.520020  2.018890e+09
# 75%     7997.372803  1.322478e+10
# max    19497.400391  7.415677e+10

# %%
df_bitcoin_search_tread.describe()
# Out:
#        BTC_NEWS_SEARCH
# count        73.000000
# mean         15.013699
# std          15.146959
# min           3.000000
# 25%           5.000000
# 50%          14.000000
# 75%          18.000000
# max         100.000000

# %%
# Are there any missing data in our tables?

# %%
df_tesla.isna() # nothing here
# Out:
#      MONTH  TSLA_WEB_SEARCH  TSLA_USD_CLOSE
# 0    False            False           False
# 1    False            False           False
# 2    False            False           False
# 3    False            False           False
# 4    False            False           False
# ..     ...              ...             ...
# 119  False            False           False
# 120  False            False           False
# 121  False            False           False
# 122  False            False           False
# 123  False            False           False
#
# [124 rows x 3 columns]

# %%
df_unemployed.isnull().values.any() # Nothing here
# Out:
# False

# %%
df_bitcoin_daily_price.isnull().values.any() # There is a null value someone
# Out:
# True

# %%
df_bitcoin_search_tread.isnull().values.any() # Clean
# Out:
# False

# %%
print("We need to find the nan value(s) in bitcoin price table and take care of it")
# Out:
# We need to find the nan value(s) in bitcoin price table and take care of it

# %%
df_bitcoin_daily_price.isnull()
# Out:
#        DATE  CLOSE  VOLUME
# 0     False  False   False
# 1     False  False   False
# 2     False  False   False
# 3     False  False   False
# 4     False  False   False
# ...     ...    ...     ...
# 2199  False  False   False
# 2200  False  False   False
# 2201  False  False   False
# 2202  False  False   False
# 2203  False  False   False
#
# [2204 rows x 3 columns]

# %%
df_bitcoin_daily_price[df_bitcoin_daily_price.isna().any(axis=1)] # Find any rows with nan values
# Out:
#             DATE  CLOSE  VOLUME
# 2148  2020-08-04    NaN     NaN

# %%
print(" We do not need this row so we can just delete it?")
# Out:
#  We do not need this row so we can just delete it?

# %%
df_bitcoin_daily_price.dropna(inplace=True)

# %%
df_bitcoin_daily_price[df_bitcoin_daily_price.isna().any(axis=1)] # Confirm we removed nan values
# Out:
# Empty DataFrame
# Columns: [DATE, CLOSE, VOLUME]
# Index: []

# %%
df_tesla.dtypes
# Out:
# MONTH              datetime64[ns]
# TSLA_WEB_SEARCH             int64
# TSLA_USD_CLOSE            float64
# dtype: object

# %%
df_unemployed.dtypes
# Out:
# MONTH                     datetime64[ns]
# UE_BENEFITS_WEB_SEARCH             int64
# UNRATE                           float64
# dtype: object

# %%
df_bitcoin_daily_price.DATE = pd.to_datetime(df_bitcoin_daily_price.DATE)

# %%
df_bitcoin_daily_price.dtypes
# Out:
# DATE      datetime64[ns]
# CLOSE            float64
# VOLUME           float64
# dtype: object

# %%
df_bitcoin_search_tread.MONTH = pd.to_datetime(df_bitcoin_search_tread.MONTH)

# %%
df_bitcoin_search_tread.dtypes
# Out:
# MONTH              datetime64[ns]
# BTC_NEWS_SEARCH             int64
# dtype: object

# %% [markdown]
# Resampling Time Series Data
# Next, we have to think about how to make our Bitcoin price and our Bitcoin search volume comparable.
# Our Bitcoin price is daily data, but our Bitcoin Search Popularity is monthly data.

# %%
print("If we need to convert a columns value to fit a different time frame we can use the resample function")
# Out:
# If we need to convert a columns value to fit a different time frame we can use the resample function

# %%
df_bitcoin_monthly_price = df_bitcoin_daily_price.resample('M', on='DATE').last()

# %%
df_bitcoin_monthly_price # Coverted daily closing price to monthly closing price considering the last 30's date price
# Out:
#                    CLOSE        VOLUME
# DATE
# 2014-09-30    386.944000  3.470730e+07
# 2014-10-31    338.321014  1.254540e+07
# 2014-11-30    378.046997  9.194440e+06
# 2014-12-31    320.192993  1.394290e+07
# 2015-01-31    217.464005  2.334820e+07
# ...                  ...           ...
# 2020-05-31   9461.058594  2.777329e+10
# 2020-06-30   9137.993164  1.573580e+10
# 2020-07-31  11323.466797  2.316047e+10
# 2020-08-31  11680.820313  2.228593e+10
# 2020-09-30  10912.536133  2.122653e+10
#
# [73 rows x 2 columns]

# %% [markdown]
# Data visualiations to better communicate our information

# %%
# This is the same axis for 2 plots
plt.figure(figsize=(8,4))
plt.ylim(0,550)


df_tesla["TSLA_USD_CLOSE"].plot()
df_tesla['TSLA_WEB_SEARCH'].plot()
# Out:
# <Axes: >

# %%
plt.figure(figsize=(14,8), dpi=400) # alter the figure
plt.xticks(fontsize=14, rotation=45) # alter x axis
plt.yticks(fontsize=14) # Alter y axis
plt.title("Tesla Web Search vs TSLA closing Price", fontsize=14)
plt.ylim(0,505) # Set the tuple representing the start and stop of the y plot axis


ax1 = plt.gca() # Get current axis
ax2 = ax1.twinx() # Same x

ax1.set_ylabel("TSLA Stock Price", color='red', fontsize=12)
ax2.set_ylabel("Search trend", fontsize=12)

ax1.plot(df_tesla['MONTH'], df_tesla['TSLA_USD_CLOSE'], color='green', linewidth=4)
ax2.plot(df_tesla['MONTH'], df_tesla['TSLA_WEB_SEARCH'], color='red', linewidth=2)

plt.show() # Ensures that outside notebook our chart will show

# %% [markdown]
# ## Using Locators and DateFormatters to generate Tick Marks on a Time Line
#
#
#
# Adding Locator Tick Marks
# When working with time series, it's often quite difficult to get the tick marks on charts looking
# the way you want to. This is why we have Locator helpers.
#
# Using Locators we can change our x-axis

# %%
# Create locators for ticks on the time axis in this case the x-axis

years = mdates.YearLocator()
months = mdates.MonthLocator()
years_fmt = mdates.DateFormatter("%Y")

# %%
plt.figure(figsize=(14,8), dpi=400) # alter the figure
plt.xticks(fontsize=14, rotation=45) # alter x axis
plt.yticks(fontsize=14) # Alter y axis
plt.title("Tesla Web Search vs TSLA closing Price", fontsize=14)
plt.ylim(0,505) # Set the tuple representing the start and stop of the y plot axis


ax1 = plt.gca() # Get current axis
ax2 = ax1.twinx() # Same x

# Add ticks on the time axis so we can more accurately judge the spikes 
ax1.xaxis.set_major_locator(years)
ax1.xaxis.set_major_formatter(years_fmt)
ax1.xaxis.set_minor_locator(months)

ax1.set_ylabel("TSLA Stock Price", color='red', fontsize=12)
ax2.set_ylabel("Search trend", fontsize=12)

ax1.plot(df_tesla['MONTH'], df_tesla['TSLA_USD_CLOSE'], color='green', linewidth=4)
ax2.plot(df_tesla['MONTH'], df_tesla['TSLA_WEB_SEARCH'], color='red', linewidth=2)

plt.show() # Ensures that outside notebook our chart will show

# %%
print("Notice the large spike in tsla stock price in March 2016.")
print("According to a google search the model 3 was unveiled this correlates in the tsla stock price increase \n")

print("Again notice the spike in stock price in 2019, this can be for a few reasons")
print("The year started with a groundbreaking on a new China factory and ended with the stock at an all-time high. \n"
"In between, Tesla revealed its Model Y SUV and a controversial Cybertruck.")
# Out:
# Notice the large spike in tsla stock price in March 2016.
# According to a google search the model 3 was unveiled this correlates in the tsla stock price increase
#
# Again notice the spike in stock price in 2019, this can be for a few reasons
# The year started with a groundbreaking on a new China factory and ended with the stock at an all-time high.
# In between, Tesla revealed its Model Y SUV and a controversial Cybertruck.

# %%
df_bitcoin_monthly_price
# Out:
#                    CLOSE        VOLUME
# DATE
# 2014-09-30    386.944000  3.470730e+07
# 2014-10-31    338.321014  1.254540e+07
# 2014-11-30    378.046997  9.194440e+06
# 2014-12-31    320.192993  1.394290e+07
# 2015-01-31    217.464005  2.334820e+07
# ...                  ...           ...
# 2020-05-31   9461.058594  2.777329e+10
# 2020-06-30   9137.993164  1.573580e+10
# 2020-07-31  11323.466797  2.316047e+10
# 2020-08-31  11680.820313  2.228593e+10
# 2020-09-30  10912.536133  2.122653e+10
#
# [73 rows x 2 columns]

# %%
df_bitcoin_search_tread
# Out:
#         MONTH  BTC_NEWS_SEARCH
# 0  2014-09-01                5
# 1  2014-10-01                4
# 2  2014-11-01                4
# 3  2014-12-01                4
# 4  2015-01-01                5
# ..        ...              ...
# 68 2020-05-01               22
# 69 2020-06-01               13
# 70 2020-07-01               14
# 71 2020-08-01               16
# 72 2020-09-01               13
#
# [73 rows x 2 columns]

# %%
plt.title("Bitcoin News Search vs Resampled price ")
plt.figure(figsize=(8,10))
plt.xticks(fontsize=12, rotation=45)
plt.yticks(fontsize=12)

ax1 = plt.gca()
ax2 = ax1.twinx()
ax1.set_ylabel("Bitcoin montly closing price")
ax2.set_ylabel("Bitcoin monthly searchs")

# Add ticks on the time axis so we can more accurately judge the spikes 
ax1.xaxis.set_major_locator(years)
ax1.xaxis.set_major_formatter(years_fmt)
ax1.xaxis.set_minor_locator(months)

ax1.set_ylim(0,15000)
ax1.set_xlim([df_bitcoin_monthly_price.index.min(), df_bitcoin_monthly_price.index.max()])

ax1.plot(df_bitcoin_monthly_price.index, df_bitcoin_monthly_price.CLOSE, color="blue", linewidth=4, linestyle='dashed')
ax2.plot(df_bitcoin_search_tread.MONTH, df_bitcoin_search_tread.BTC_NEWS_SEARCH, color="red", linewidth=2, marker='o')


plt.show()

# %%
df_unemployed.UNRATE
# Out:
# 0       5.7
# 1       5.6
# 2       5.8
# 3       5.6
# 4       5.6
#        ...
# 195    14.7
# 196    13.3
# 197    11.1
# 198    10.2
# 199     8.4
# Name: UNRATE, Length: 200, dtype: float64

# %%
plt.figure(figsize=(10,12)) # Must be set first

plt.title("Monthly Search of 'Unemployment Benefits' in the U.S vs the U/E Rate")
plt.xticks(fontsize=12, rotation=45)
plt.yticks(fontsize=12)

ax1 = plt.gca()
ax2 = ax1.twinx()
ax1.set_ylabel("FRED U/E Rate")


# Add ticks on the time axis so we can more accurately judge the spikes 
ax1.xaxis.set_major_locator(years)
ax1.xaxis.set_major_formatter(years_fmt)
ax1.xaxis.set_minor_locator(months)


ax1.grid(color='grey', linestyle='--')
line1, = ax1.plot(df_unemployed.MONTH, df_unemployed.UE_BENEFITS_WEB_SEARCH, color="blue", linewidth=4, linestyle='dashed', label="UE benefit search") 
line2, = ax2.plot(df_unemployed.MONTH, df_unemployed.UNRATE, color="red", linewidth=2, marker='o', label="Unemployment Rate") # Combine the legends from both axes 


lines = [line1, line2] 
labels = [line.get_label() for line in lines] 
ax1.legend(lines, labels, loc='upper left')


plt.legend()
plt.show()

# %%
print("The relationship between the unemployment rate and unemployement benefit search is easily noticed on this graph")
# Out:
# The relationship between the unemployment rate and unemployement benefit search is easily noticed on this graph

# %%
roll_df = df_unemployed.UE_BENEFITS_WEB_SEARCH.rolling(window=6).mean()

# %%
roll_df
# Out:
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
#          ...
# 195    27.666667
# 196    37.500000
# 197    45.500000
# 198    53.666667
# 199    61.166667
# Name: UE_BENEFITS_WEB_SEARCH, Length: 200, dtype: float64

# %%
plt.figure(figsize=(14,8), dpi=120)
plt.title('Rolling Monthly US "Unemployment Benefits" Web Searches vs UNRATE', fontsize=18)
plt.yticks(fontsize=14)
plt.xticks(fontsize=14, rotation=45)
 
ax1 = plt.gca()
ax2 = ax1.twinx()
 
ax1.xaxis.set_major_locator(years)
ax1.xaxis.set_major_formatter(years_fmt)
ax1.xaxis.set_minor_locator(months)
 
ax1.set_ylabel('FRED U/E Rate', color='purple', fontsize=16)
ax2.set_ylabel('Search Trend', color='skyblue', fontsize=16)
 
ax1.set_ylim(bottom=3, top=10.5)
ax1.set_xlim([df_unemployed.MONTH[0], df_unemployed.MONTH.max()])
 
# Calculate the rolling average over a 6 month window
roll_df = df_unemployed[['UE_BENEFITS_WEB_SEARCH', 'UNRATE']].rolling(window=6).mean()
 
ax1.plot(df_unemployed.MONTH, roll_df.UNRATE, 'purple', linewidth=3, linestyle='-.')
ax2.plot(df_unemployed.MONTH, roll_df.UE_BENEFITS_WEB_SEARCH, 'skyblue', linewidth=3)
 
plt.show()

# %% [raw]
# What is this telling us? We see that searches for "Unemployment Benefits" happen before the actual official unemployment rate goes up. Similarly, the search popularity for the term goes down before the unemployment rate decreases. In other words, these searches seem to act as a leading economic indicator for the unemployment rate (which is a lagging indicator).

# %%
df_ue_2020 = pd.read_csv('UE Benefits Search vs UE Rate 2004-20.csv')
df_ue_2020.MONTH = pd.to_datetime(df_ue_2020.MONTH)

# %%
plt.figure(figsize=(14,8), dpi=120)
plt.yticks(fontsize=14)
plt.xticks(fontsize=14, rotation=45)
plt.title('Monthly US "Unemployment Benefits" Web Search vs UNRATE incl 2020', fontsize=18)
 
ax1 = plt.gca()
ax2 = ax1.twinx()
 
ax1.set_ylabel('FRED U/E Rate', color='purple', fontsize=16)
ax2.set_ylabel('Search Trend', color='skyblue', fontsize=16)
 
ax1.set_xlim([df_ue_2020.MONTH.min(), df_ue_2020.MONTH.max()])
 
ax1.plot(df_ue_2020.MONTH, df_ue_2020.UNRATE, 'purple', linewidth=3)
ax2.plot(df_ue_2020.MONTH, df_ue_2020.UE_BENEFITS_WEB_SEARCH, 'skyblue', linewidth=3)
 
plt.show()
